# %%
#IMPORTING THE REQUIRDD LIBRARIES
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get('https://www.google.com/search?q=Professionally+Shot+Bedroom+Images+in+usa')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-IN"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Professionally Shot Bedroom Images in usa - Google Search</title><script nonce="a8N9iWCwkK21Bzwqt_yJnA">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    Professionally Shot Bedroom Images in usa - Google Search
#   </title>
#   <script nonce="a8N9iWCwkK21Bzwqt_yJnA">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#First,we will use html tag where we have the first title of the restaurants
first_image = soup.find('img',class_="WddBJd")
first_image
# Out:
# <img alt="www.boxbrownie.com/img/uploads/3.1.jpg" class="WddBJd" data-deferred="1" id="dimg_17" src="..." style="max-width:none;height:128px;max-height:128px"/>

# %%
image_tags = soup.find_all('img', class_='WddBJd')
image_tags
# Out:
# [<img alt="www.boxbrownie.com/img/uploads/3.1.jpg" class="WddBJd" data-deferred="1" id="dimg_17" src="..." style="max-width:none;height:128px;max-height:128px"/>,
#  <img alt="www.boxbrownie.com/img/uploads/4.1.jpg" class="WddBJd" data-deferred="1" id="dimg_19" src="..." style="max-width:none;height:128px;max-height:128px"/>,
#  <img alt="static.photocdn.pt/images/articles/2019/02/20/How_..." class="WddBJd" data-deferred="1" id="dimg_21" src="..." style="max-width:none;height:128px;max-height:128px"/>,
#  <img alt="www.boxbrownie.com/img/uploads/2.1.jpg" class="WddBJd" data-deferred="1" id="dimg_23" src="..." style="max-width:none;height:128px;max-height:128px"/>,
#  <img alt="thumbs.dreamstime.com/b/blue-scandinavian-bedroom-..." class="WddBJd" data-deferred="1" id="dimg_25" src="..." style="max-width:none;height:128px;max-height:128px"/>,
# ...

# %%
print(len(image_tags))
# Out:
# 6

# %%
second_image = soup.find('img',class_="Dk7jOe")
second_image
# Out:
# <img alt="" class="Dk7jOe" data-deferred="1" id="dimg_29" src="..." style="max-width:24px;max-height:24px"/>

# %%
image_tags = soup.find_all('img', class_='Dk7jOe')
image_tags
# Out:
# [<img alt="" class="Dk7jOe" data-deferred="1" id="dimg_29" src="..." style="max-width:24px;max-height:24px"/>]

# %%
new_image_tags= soup.find_all('div',class_='Gx5Zad fP1Qef xpd EtOod pkphOe')
new_image_tags
# Out:
# [<div class="Gx5Zad fP1Qef xpd EtOod pkphOe"><div class="egMi0 kCrYT"><a href="/url?q=https://www.dreamstime.com/photos-images/bedroom-shot.html&amp;sa=U&amp;ved=2ahUKEwi4jfvCtsD4AhW9ArkGHfRGCccQFnoECAUQAg&amp;usg=AOvVaw2lnQO9eCm_nBDp7T33hYyS"><h3 class="zBAuLc l97dzf"><div class="BNeawe vvjwJb AP7Wnd">12328 Bedroom Shot Stock Photos - Dreamstime.com</div></h3><div class="BNeawe UPmit AP7Wnd">www.dreamstime.com › Stock Photos</div></a></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="BNeawe s3v9rd AP7Wnd">Your Bedroom Shot stock images are ready. Download all free or royalty-free photos and images. Use them in commercial designs under lifetime, ...</div></div></div></div></div></div></div>,
# ...
